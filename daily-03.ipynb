# %%
import openai

client = openai.OpenAI()
messages = []

# %%
def call_ai():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
    )
    message = response.choices[0].message.content
    messages.append({"role": "assistant", "content":message})
    print(f"AI: {message}")

# %%
while True:
    message = input("메시지를 임력하세요...")
    if message == "quit" or message == "q":
        break
    else:
        messages.append({
            "role": "user",
            "content": message,
        })
        print(f"User: {message}")
        call_ai()
# Out:
# User: 나는 SF 영화를 좋아해
# AI: SF 영화는 정말 흥미로운 장르죠! 미래의 기술, 외계 생명체, 시간 여행 등의 다양한 주제를 다룰 수 있어 매력이 많습니다. 어떤 SF 영화를 가장 좋아하시나요? 또는 추천받고 싶은 영화가 있으신가요?
# User: 인셉션이랑 인터스텔라는 이미 봤어
# AI: 두 영화 모두 크리스토퍼 놀런 감독의 작품으로, 복잡하고 깊이 있는 스토리와 시각적인 매력이 정말 인상적이죠. 인셉션은 꿈과 현실의 경계를 다루고, 인터스텔라는 우주 탐사와 사랑에 대한 이야기로 유명합니다.
#
# 혹시 이러한 스타일의 다른 SF 영화를 찾고 계신가요? "메멘토", "닥터 스트레인지러브", "블레이드 러너"와 같은 영화도 추천해 드리고 싶습니다. 어떤 유형의 SF 영화를 더 선호하시나요?
# User: 오늘 밤에 뭐 볼지 추천해 줄래?
# AI: 물론이죠! 오늘 밤에 볼 만한 SF 영화를 몇 가지 추천해 드릴게요.
#
# 1. **이너스페이스 (Innerspace)** - 과학 실험 중에 축소된 주인공이 인체 내부로 들어가면서 벌어지는 모험을 다룬 코미디 같은 SF 영화입니다.
#
# 2. **엑스 마키나 (Ex Machina)** - 인공지능(AI)의 윤리와 인간의 감정을 깊이 있게 탐구하는 영화로, 긴장감 넘치는 스토리와 뛰어난 연기가 돋보입니다.
#
# 3. **테넷 (Tenet)** - 시간의 흐름을 뒤틀어 새로운 차원의 이야기로 만들어낸 스릴러로, 놀란 감독의 독창적인 스타일이 잘 드러납니다.
#
# 4. **그라비티 (Gravity)** - 우주에서의 생존을 다룬 영화로, 시각적으로 아름답고 긴장감 넘치는 장면들이 많습니다.
#
# 5. **프리스트 (Predestination)** - 시간 여행과 정체성을 주제로 한 복잡한 스토리를 가진 영화로, 반전이 인상적입니다.
#
# 이 중에서 어떤 영화가 마음에 드시나요?
# User: 내가 좋아하는 장르랑 이미 본 영화가 뭐라고 했지?
# AI: 당신이 좋아하는 장르는 SF 영화이고, 이미 보신 영화로는 **인셉션**과 **인터스텔라**가 있다고 말씀하셨습니다. 이 두 영화는 복잡한 플롯과 깊이 있는 주제를 다루고 있어서, 정말 많은 사람들이 사랑하는 작품이죠! 다른 추천영화나 궁금한 점이 있으면 언제든지 말씀해 주세요.
